# %% [markdown]
# #### DATA PROFILING
#
# - Here we will understand the data.
# 1. What data is this?
# 2. What each feature describes ?
# 3. What changes needed to perform for analysis and meeting end business goals ?
# 4. What is expected output ?
# 5. What are key performance features ?

# %%
# ---- HEALTH CARE DATA ----
from ydata_profiling import ProfileReport
import pandas as pd

df = pd.read_csv(r"C:\Users\PANRIT\ALL\Pranit Main\Study\Data Analytics\2_Data_Preparation\1_data_profiling\case study\1_HealthCare.csv", encoding="latin1")
# profile = ProfileReport(df, title="HealthCare Profiling", explorative=True)
# profile.to_file("Health Care.html")
# print("Your Data Profile is ready")
df
